# %% [markdown]
# <a href="https://colab.research.google.com/github/boomyun713/114_homework/blob/main/W11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.0)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.18.3)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2025.11.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.23)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import google.generativeai as genai
import os
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import yfinance as yf
import datetime as dt
import time

class StockInfo():
    def stock_name(self):
        response = requests.get('https://isin.twse.com.tw/isin/C_public.jsp?strMode=2')
        url_data = BeautifulSoup(response.text, 'html.parser')

        stock_company = url_data.find_all('tr')


        data = [
            (row.find_all('td')[0].text.split('\u3000')[0].strip(),
                row.find_all('td')[0].text.split('\u3000')[1],
                row.find_all('td')[4].text.strip())
            for row in stock_company[2:] if len(row.find_all('td')[0].text.split('\u3000')[0].strip()) == 4
        ]

        df = pd.DataFrame(data, columns=['股號', '股名', '產業別'])
        return df

    def get_stock_name(self, stock_id, name_df):
        return name_df.set_index('股號').loc[stock_id, '股名']

# %%
class StockAnalysis():
    def __init__(self, gemini_api_key):
        genai.configure(api_key=gemini_api_key)
        self.model = genai.GenerativeModel('gemini-2.5-pro')
        self.stock_info = StockInfo()
        self.name_df = self.stock_info.stock_name()


    def stock_price(self, stock_id, days=15):
        stock_id += '.TW'
        end = dt.date.today()
        start = end - dt.timedelta(days=days)

        import warnings
        warnings.filterwarnings('ignore', category=FutureWarning)

        df = yf.download(stock_id, start=start, auto_adjust=True)

        df.columns = ['開盤價', '最高價', '最低價', '收盤價', '成交量']
        data = {
            '日期': df.index.strftime('%Y-%m-%d').tolist(),
            '收盤價': df['收盤價'].tolist(),
            '每日報酬': df['收盤價'].pct_change().tolist()
        }
        return data


    def stock_fundamental(self, stock_id):
        stock_id += '.TW'
        stock = yf.Ticker(stock_id)

        try:
            quarterly_revenue_growth = np.round(
                stock.quarterly_financials.loc['Total Revenue'].pct_change(-1, fill_method=None).dropna().tolist(),
                2
            )
            quarterly_eps = np.round(
                stock.quarterly_financials.loc['Basic EPS'].dropna().tolist(),
                2
            )

            quarterly_eps_growth = np.round(
                stock.quarterly_financials.loc['Basic EPS'].pct_change(-1, fill_method=None).dropna().tolist(),
                2
            )
            dates = [date.strftime('%Y-%m-%d') for date in stock.quarterly_financials.columns]
            data = {
                '季日期': dates[:len(quarterly_revenue_growth)],
                '營收成長率': quarterly_revenue_growth.tolist(),
                'EPS': quarterly_eps.tolist(),
                'EPS 季增率': quarterly_eps_growth.tolist()
            }
        except Exception as e:
            print(f"無法取得 {stock_id} 基本面資料: {e}")
            data = {'季日期': [], '營收成長率': [], 'EPS': [], 'EPS 季增率': []}

        return data

    def _get_reply(self, content_msg):
        try:
            response = self.model.generate_content(
                content_msg,
                generation_config=genai.types.GenerationConfig(
                    max_output_tokens=10000,
                    temperature=1.0,
                )
            )

            if not response.candidates:
                return "模型未返回任何回應"

            candidate = response.candidates[0]
            finish_reason = candidate.finish_reason
            if finish_reason == 1:
                return candidate.content.parts[0].text

            elif finish_reason == 2:
                try:
                    partial_text = candidate.content.parts[0].text if candidate.content.parts else ""
                    return f"{partial_text}\\n\\n [回應被截斷，已達到長度限制]"
                except:
                    return "回應超過長度限制。建議：1)增加 max_output_tokens 2)簡化 prompt"

            elif finish_reason == 3:
                return "模型因安全政策無法提供回應"

            elif finish_reason == 4:
                return "回應因引用問題被過濾"

            else:
                return f"未知完成原因: {finish_reason}"

        except Exception as e:
            error_msg = str(e)
            if "429" in error_msg or "RESOURCE_EXHAUSTED" in error_msg:
                return "達到 API 速率限制（免費層：5次/分鐘，25次/天）"
            elif "503" in error_msg:
                return "服務暫時不可用，請稍後重試"
            else:
                return f"API 錯誤: {error_msg}"


    def stock_gimini_analysis(self, stock_id):
        stock_name = self.stock_info.get_stock_name(stock_id, self.name_df)

        price_data = self.stock_price(stock_id)
        print('資料收集完畢')
        stock_value_data = self.stock_fundamental(stock_id)
        summary_parts = []

        if price_data and price_data['收盤價']:
            latest = price_data['收盤價'][-1]
            first = price_data['收盤價'][0]
            change = ((latest - first) / first) * 100
            summary_parts.append(f"股價：{latest:.2f} (兩週 {change:+.2f}%)")

        if stock_value_data and stock_value_data['季日期']:
            q = stock_value_data['季日期'][0]
            rev = stock_value_data['營收成長率'][0]
            eps = stock_value_data['EPS'][0]
            summary_parts.append(f"基本面({q})：營收成長{rev*100:.1f}%, EPS {eps:.2f}")

        combined = "；".join(summary_parts)
        content_msg = f'''你是成長型投資顧問...
    針對股票 {stock_name}。
    1. 關注營收成長動能
    2. 尋找突破訊號...
資料：{combined}'''
        reply = self._get_reply(content_msg)
        return reply


    def stock_gimini_sort(self, message):
        content_msg = f'''你是專業股票分析師，根據趨勢報告評分(0-100)。
50分為基準，正面消息加分，負面消息扣分。
排序所有股票。{str(message)}(繁體中文)'''
        reply = self._get_reply(content_msg)
        return reply


    def stock_gimini_choice(self, message):
        content_msg = f'''你是專業證券分析師，從趨勢報告中選出最適合投資的一檔股票。
即使都不理想也要選一檔，說明理由。{str(message)}(繁體中文)'''
        reply = self._get_reply(content_msg)
        return reply

# %%
gemini_api_key = 'AIzaSyA4N6wfuhPggA_porf9x44gJ0Ihb7XY3_Y'
stock_analysis = StockAnalysis(gemini_api_key)

# %%
reply = stock_analysis.stock_gimini_analysis('2454')

print(reply)
# Out:
# [*********************100%***********************]  1 of 1 completed
# 資料收集完畢
# 好的，我是您的成長型投資顧問。針對聯發科 (2454)，我們將從您關注的「營收成長動能」與「技術面突破訊號」這兩個核心角度，進行深入剖析。
#
# 首先，您提供的數據點：**股價 1175.00 (兩週 -6.00%)**，這反映了市場短期的修正與觀望氣氛。而**基本面(2025-09-30)預估：營收成長-6.0%, EPS 15.84**，這個未來預測數據偏向保守，與目前市場主流的樂觀預期有所出入。我們將以此為基礎，進行全面的評估。
#
# ### **總結：短期震盪盤整，長期AI成長故事不變**
#
# 聯發科目前正處於「長期利多」與「短期雜音」的交戰期。股價從前高回落，反映了市場對整體手機市況復甦力道、以及AI題材實現為營收的時程，出現了短期疑慮。然而，其在AI手機晶片的領導地位，以及業務多元化的潛力，依然是成長型投資的核心基石。
#
# ---
#
# ### **1. 營收成長動能分析 (The Growth Engine)**
#
# 成長型投資的核心是尋找能持續擴大營收的公司。我們來看看聯發科的引擎是否依然強勁。
#
# #### **核心成長驅動力 (Positive Catalysts):**
#
# 1.  **AI 手機晶片規格升級與高 ASP (平均售價):**
#     *   **天璣9300/9400系列：** 這是聯發科最重要的武器。天璣9300的成功已證明其能與高通 Snapdragon 在旗艦市場一較高下。即將推出的 9400 採用更先進的製程 (台積電N3)，將進一步鞏固其在「終端AI (Edge AI)」的領導地位。
#     *   **價值提升：** AI 功能對晶片運算能力要求更高，這意味著更高階的晶片設計與更高的售價 (ASP)。即使手機總量成長有限，ASP 的提升也能直接帶動營收成長。這是最重要的成長故事。
#
# 2.  **旗艦市場市佔率提升：**
#     *   過去聯發科主攻中低階市場，但現在已成功打入中國一線品牌 (如 VIVO, OPPO, 小米) 的旗艦機型。這不僅提升了營收，更重要的是改善了毛利率與品牌形象。
#
# 3.  **業務多元化佈局：**
#     *   **車用電子 (Dimensity Auto)：** 與 Nvidia 合作的智慧座艙晶片是長期一大亮點。車用晶片認證期長，但一旦打入供應鏈，訂單能見度高且穩定。
#     *   **ASIC (客製化晶片)：** 傳聞為美系雲端服務供應商 (CSP) 開發客製化晶片，若能成功，將是打入雲端AI市場的重大里程碑，開闢全新的成長曲線。
#     *   **WiFi-7 與物聯網 (IoT)：** 穩定貢獻營收，是公司營運的堅實基礎。
#
# #### **潛在風險與逆風 (Headwinds):**
#
# 1.  **全球手機市場復甦不如預期：** 這是最大的不確定性。如果總體經濟疲軟，消費者換機意願低落，將直接衝擊聯發科的出貨量。您提供的「營收成長-6.0%」預測，可能就反映了這種擔憂。
# 2.  **競爭加劇：** 高通 (Qualcomm) 依然是強大的對手，其 Snapdragon 系列在品牌與效能上仍有優勢。三星 (Samsung) Exynos 的捲土重來也可能擾亂市場。激烈的競爭可能導致價格戰，侵蝕利潤。
# 3.  **庫存調整週期：** 半導體產業具有週期性，下游手機品牌廠的庫存水位會影響拉貨力道，造成短期營收波動。
#
# **動能小結：**
# 雖然您提供的未來數據偏保守，但市場共識普遍認為，**AI 將驅動新一波換機潮並提升晶片價值**。聯發科的成長動能，短期內看旗艦機市佔率，長期則看 AI 應用滲透率以及車用、ASIC 等新業務的開花結果。目前看來，長期成長故事依然完整。
#
# ---
#
# ### **2. 尋找技術面突破訊號 (The Breakout Signals)**
#
# 股價的短期修正提供了觀察切入點的機會。我們需要尋找從「整理」轉為「攻擊」的訊號。
#
# #### **目前盤勢：高檔回落，尋求支撐**
#
# 目前股價 1175 元，距離前高 1310 元已有一段跌幅，呈現量縮盤整格局。這表示多空雙方在此價位區間暫時達到平衡，正在等待新的催化劑。
#
# #### **你需要關注的「多頭突破訊號」：**
#
# 1.  **帶量突破下降趨勢線/前波高點：**
#     *   **觀察點：** 畫出近期高點連接的下降壓力線，當股價以一根「**長紅K棒**」伴隨「**顯著大於月均量的成交量**」向上突破時，是初步的攻擊訊號。
#     *   **關鍵價位：** **1200元** 是一個重要的心理與技術關卡，若能站穩其上，將是轉強的第一步。更強的訊號則是挑戰並突破前高 **1300元** 附近。
#
# 2.  **站穩關鍵均線之上：**
#     *   **月線 (20MA) 與季線 (60MA)：** 目前股價可能在季線附近徘徊。若能重新站回月線之上，且月線開始走平向上，代表短期趨勢扭轉。最強的訊號是股價在季線之上獲得支撐後，放量反攻。
#     *   **觀察點：** 留意股價在 **季線（目前約在 1150 元附近）** 是否有出現「**下引線**」或「**紅K吞噬黑K**」的止跌訊號。
#
# 3.  **法人籌碼由賣轉買：**
#     *   **觀察指標：** 外資、投信的連續買超。尤其是在股價整理末端，若觀察到**投信**開始積極回補（通常代表內資看好），或**外資**結束連續賣超轉為買超，都是非常正面的籌碼訊號。
#
# #### **你需要警惕的「跌破訊號」：**
#
# *   **帶量跌破季線/頸線支撐：** 如果股價不僅跌破季線，還跌破前波低點（例如 **1100元** 的整數關卡），且伴隨成交量放大，則表示整理時間可能拉長，需嚴格執行停損或減碼。
#
# ---
#
# ### **策略建議**
#
# 身為成長型投資顧問，我不會建議您在趨勢不明時貿然投入所有資金。
#
# 1.  **積極型投資人：**
#     *   **策略：** 左側思維，分批佈局。
#     *   **作法：** 可在股價回測關鍵支撐區（如季線或 1100 元附近）且出現量縮止穩時，建立**基本部位 (約1/3資金)**。這樣做的好處是成本較低，但需承受盤整或進一步下跌的風險。
#
# 2.  **穩健型投資人：**
#     *   **策略：** 右側思維，等待確認。
#     *   **作法：** 耐心等待上述的「多頭突破訊號」出現。例如，等待股價**明確帶量站回 1200 元以上**，或甚至突破下降趨勢線後，再進場追蹤。雖然成本較高，但趨勢的確定性也更高。
#
# **無論採取何種策略，都應持續追蹤以下基本面催化劑：**
# *   每月營收公布是否優於預期。
# *   下一代天璣9400的發表時程與客戶採用情況。
# *   車用電子、ASIC業務是否有新的訂單或合作消息。
#
# **免責聲明：** 以上分析為基於現有資訊的投資觀點分享，並非任何形式的買賣建議。股市有風險，投資前請務必獨立思考，並做好個人風險控管。

# %%
stock_list = ['2882', '2881', '2891']
today_time = dt.date.today().strftime('%Y%m%d')
path = './StockGemini/TrendReport/'
os.makedirs(path, exist_ok=True)

content = {}

print(f"\n{'='*70}")
print(f"開始分析 {len(stock_list)} 檔股票")
print(f"{'='*70}\n")

for i, stock in enumerate(stock_list, 1):
    print(f"[{i}/{len(stock_list)}] 處理股票: {stock}")

    file_path = f"{path}trend_{stock}_{today_time}.txt"

    if not os.path.exists(file_path):
        try:

            print(f"   正在分析...")
            analysis = stock_analysis.stock_gimini_analysis(stock_id=stock)

            with open(file_path, "w", encoding="utf-8") as f:
                f.write(analysis)

            content[stock] = analysis
            print(f"   分析完成並已儲存\n")

            if i < len(stock_list):
                wait_time = 12
                print(f"   等待 {wait_time} 秒以符合 API 速率限制...\n")
                time.sleep(wait_time)

        except Exception as e:
            error_msg = f"錯誤: {str(e)}"
            print(f"   {error_msg}\n")
            content[stock] = error_msg

    else:
        with open(file_path, "r", encoding="utf-8") as f:
            content[stock] = f.read()
        print(f"   從快取讀取\n")

print(f"{'='*70}")
print("所有股票分析完成！")
print(f"{'='*70}\n")

print("\n" + "="*70)
print("分析結果")
print("="*70 + "\n")

for stock_id, analysis in content.items():
    stock_name = stock_analysis.stock_info.get_stock_name(stock_id, stock_analysis.name_df)

    print("="*70)
    print(f"【{stock_id} - {stock_name}】")
    print("="*70)
    print(analysis)
    print("\n")
# Out:
# ======================================================================
# 開始分析 3 檔股票
# ======================================================================
#
# [1/3] 處理股票: 2882
#    正在分析...
# [*********************100%***********************]  1 of 1 completed
# 資料收集完畢
#    分析完成並已儲存
#
#    等待 12 秒以符合 API 速率限制...
#
# [2/3] 處理股票: 2881
#    正在分析...
# [*********************100%***********************]  1 of 1 completed
# 資料收集完畢
#    分析完成並已儲存
#
#    等待 12 秒以符合 API 速率限制...
#
# [3/3] 處理股票: 2891
#    正在分析...
# [*********************100%***********************]  1 of 1 completed
# 資料收集完畢
#    分析完成並已儲存
#
# ======================================================================
# 所有股票分析完成！
# ======================================================================
#
#
# ======================================================================
# 分析結果
# ======================================================================
#
# ======================================================================
# 【2882 - 國泰金】
# ======================================================================
# 好的，您好。我是您的成長型投資顧問。很高興能為您分析國泰金 (2882)，我們將從您最關注的「營收成長動能」與「突破訊號」這兩個核心角度，來進行深入探討。
#
# 首先，我們必須釐清並解讀您提供的數據：
# *   **股價：** 65.50元 (近兩週上漲2.99%) -> **市場情緒偏多，股價處於強勢。**
# *   **基本面(2025-06-30)：** 營收成長-77.0%, EPS 0.71 -> **這是一個極其關鍵且需要解讀的訊號。**
#
# **數據解讀與初步分析：**
#
# 您提供的基本面數據日期為「2025-06-30」，這是一個未來的日期，我推斷這可能是預測值或是數據來源的標示錯誤。我將以近期已發生的事實和市場共識來進行分析。
#
# 最引人注目的是 **營收成長-77.0%**。對於任何公司，這都是一個巨大的警訊。但作為金融控股公司，其營收（主要為淨收益）的構成非常特殊，包含：
# 1.  **穩定型收入：** 銀行淨利息收入、淨手續費收入。
# 2.  **波動型收入：** 人壽的保險業務收益與巨額的**投資收益**。
#
# 這個「-77%」的數字，極大概率是來自於「投資收益」的劇烈波動。可能是與去年同期的投資高基期相比，或是某個季度的投資虧損所致。**因此，作為成長型投資顧問，我們不能只看這個總數，必須拆解其背後的動能。**
#
# ---
#
# ### **1. 關注營收成長動能 (Deconstructing Revenue Growth Momentum)**
#
# 從成長投資的角度來看，我們要尋找的是**可持續、高品質**的成長，而非一次性的投資收益。
#
# **核心動能分析：**
#
# *   **國泰人壽（獲利心臟，也是波動來源）：**
#     *   **動能一 (利差益)：** 全球進入高利率環境尾聲，甚至未來可能降息。壽險業過去賣的高利率保單虧損壓力（利差損）將逐步緩解。同時，新錢投放在高利率的債券上，能鎖定未來幾年的穩定收益。**這是一個長期的、結構性的改善動能。**
#     *   **動能二 (投資收益)：** 這是雙面刃。當股市（如台股、美股）表現強勁時，國泰金持有的大量股票部位會帶來巨大的資本利得，EPS會暴衝。反之，市場修正時也會帶來虧損。目前的台股位於兩萬點之上，為其帶來了豐厚的未實現利益，是**當前EPS靚麗的主因，但也是未來潛在的風險。**
#     *   **動能三 (業務價值)：** 新契約保單價值（VNB）的成長。這代表了未來可持續的獲利能力，需要關注其高價值保單的銷售情況。
#
# *   **國泰世華銀行（穩定增長引擎）：**
#     *   **動能一 (淨利息收入)：** 升息循環雖然可能見頂，但只要利率維持在相對高檔，銀行的存放款利差就能維持在不錯的水準。企業貸款與個人信貸的需求是觀察重點。
#     *   **動能二 (淨手續費收入)：** 財富管理業務是關鍵。隨著高資產客戶增加，這塊業務的成長潛力巨大且穩定。這是**高品質成長的代表**。
#
# **成長顧問小結：**
# 國泰金的「成長故事」並非傳統科技股的營收飆升，而是一個**「週期性成長」**的故事。當前的成長動能主要由**壽險端的投資收益**所驅動，這是順風下的強力催化劑。然而，更值得我們關注的長期動能，來自於**銀行業務的穩健擴張**以及**壽險業利差損的結構性改善**。您看到的-77%營收衰退，很可能是短期投資波動造成的雜訊，掩蓋了其核心業務的長期改善趨勢。
#
# ---
#
# ### **2. 尋找突破訊號 (Searching for Breakthrough Signals)**
#
# 股價要形成突破，需要技術面、基本面、籌碼面三者共振。
#
# **技術面訊號：**
#
# 1.  **關鍵價位突破：** 目前股價65.5元，已經站上了長達20年的**超級大頸線**（約在58-60元區間）。能夠站穩在這個位置之上，本身就是一個極強的技術面突破訊號，代表長期壓力轉為支撐。
# 2.  **量價關係：** 觀察近期突破關鍵價位時，是否**「帶量上攻」**。如果上漲伴隨著成交量顯著放大，代表市場認同度高，籌碼換手成功，突破的有效性更強。
# 3.  **均線排列：** 檢查5日、20日、60日均線是否呈現**「多頭排列」**（短天期在長天期之上）。這是趨勢走強的標準訊號。目前國泰金已呈現此態勢。
# 4.  **下一個目標：** 突破當前平台後，下一個心理關卡可能是70元整數關卡，甚至是2007-2008年的高點區域。
#
# **基本面訊號：**
#
# 1.  **月自結盈餘（最重要的領先指標）：** 金融股每月10號左右會公佈上個月的自結EPS。**連續數月超出市場預期**的獲利數字，是股價上漲最硬的底氣。這是您必須密切追蹤的訊號。
# 2.  **法說會展望：** 關注公司管理層在法說會上對於未來景氣、投資佈局、股利政策的看法。若釋放出遠優於預期的樂觀指引，將會是強力的催化劑。
# 3.  **總體經濟數據：** 美國聯準會（Fed）的利率決策。若明確釋放**「預防性降息」**訊號，而非因經濟衰退而降息，通常對股市有利，將直接助燃國泰金的投資收益。
#
# **籌碼面訊號：**
#
# 1.  **外資動向：** 作為大型權值股，**外資的連續性買超**是股價上漲不可或缺的推手。觀察外資持股比例的變化與買賣超的連續性。
# 2.  **投信持股：** 若國內投信開始將國泰金納入高股息ETF或一般基金的核心持股並持續加碼，將提供穩定的買盤。
# 3.  **融資融券：** 觀察融資餘額。若股價上漲而融資餘額穩定或小幅增加，代表籌碼相對安穩。若融資暴增，則需提防過熱風險。
#
# ---
#
# ### **成長顧問綜合觀點與策略**
#
# **定位：**
# 國泰金並非典型的「高速成長股」，它更像一頭**「甦醒的金融巨象」**。其成長模式是**「順週期 + 結構性改善」**。在股市多頭、利率環境有利的背景下，它能展現出驚人的獲利爆發力。
#
# **當前情勢：**
# *   **優勢：** 技術面已呈現突破姿態，基本面受惠於股市多頭，EPS表現亮眼，長期利差損問題正在改善。
# *   **風險：** 獲利與股市高度連動，若全球股市出現大幅度修正，其股價也將面臨壓力。這是成長型投資必須承受的波動風險。
#
# **策略建議：**
#
# 1.  **核心觀察點：** 請將焦點從「總營收年增率」這個充滿雜訊的指標，轉移到**「每月自結EPS」**以及**「外資買賣超動向」**這兩個最即時、最關鍵的訊號上。
# 2.  **操作思維：**
#     *   **對於積極的成長型投資者：** 目前技術面突破訊號已出現。可以考慮在股價回測頸線支撐（約58-60元）不破時，或在帶量突破近期高點時，分批佈局。這是一個**「順勢操作」**的策略。
#     *   **停損設定：** 必須設定紀律。若股價跌破關鍵支撐區（如月線或前波突破的頸線），且伴隨著外資連續大賣或月EPS不如預期，應考慮減碼或停損。
#
# **總結來說，國泰金目前正處於一個多年未見的有利環境，技術面與短期基本面均發出了積極訊號。作為成長型投資顧問，我認為它具備了成為下一階段市場領漲股的潛力，但您必須清楚認知其成長動能與股市高度相關的「順週期」特性，並據此做好風險控管。**
#
# ***
# *免責聲明：以上分析為基於現有資訊的投資觀點分享，不構成任何買賣建議。所有投資決策應由您自行研究判斷，並承擔相應風險。*
#
#
# ======================================================================
# 【2881 - 富邦金】
# ======================================================================
# 好的，您好。身為您的成長型投資顧問，我們來深入剖析富邦金(2881)，並專注於您提到的兩大核心：**營收成長動能**與**突破訊號**。
#
# 首先，關於您提供的基本面數據，我必須先做一個澄清與校準：
# `基本面(2025-06-30)：營收成長-97.0%, EPS 0.48`
# 這個數據點可能有誤或需要更完整的脈絡。2025年尚未到來，而-97%的營收衰退通常是因前一年度有鉅額的單次性收入（例如處分資產）所造成的「高基期效應」，並不能完全反映當前的業務實況。
#
# 因此，我將以截至目前（2024年第一季及最新月報）的公開資訊，為您提供更精確的分析。
#
# ---
#
# ### **核心觀點：順風週期的資產放大器**
#
# 富邦金目前正處於一個「順風週期」。它不像高科技成長股那樣靠產品創新驅動，而是像一個**資產放大器**：當金融市場（股市、債市）表現強勁時，其獲利能力會被顯著放大。目前的成長動能主要來自於此，而非傳統業務的爆炸性增長。
#
# ---
#
# ### **1. 營收成長動能剖析 (Growth Momentum)**
#
# 富邦金的獲利來源主要分為三大引擎：**壽險、銀行、證券**。目前的成長動能也由此構成。
#
# #### **A. 主要驅動力：富邦人壽的投資收益**
# *   **動能來源**：這是當前富邦金獲利爆發的核心。受惠於全球股市（特別是美股AI概念股）及台股的大多頭行情，富邦人壽持有的龐大股債部位實現了可觀的資本利得。
# *   **觀察指標**：每月公布的自結稅後純益。今年以來，富邦金多次單月EPS突破1元，主要貢獻都來自壽險子公司。
# *   **成長性質**：這種成長是**順週期性**且**波動性高**的。它與大盤指數高度相關，而非來自保費收入的穩定增長。可以說，**買現階段的富邦金，有很大一部分是在押注股市會繼續維持高檔**。
#
# #### **B. 穩定貢獻者：台北富邦銀行的穩健利差與手收**
# *   **動能來源**：
#     1.  **利差收入**：雖然央行利率持平，但銀行的放款業務仍能提供穩定的淨利息收入（NIM）。
#     2.  **手續費收入**：財富管理、信用卡業務（特別是Costco聯名卡帶來大量活躍用戶）是穩定的現金流來源。
# *   **成長性質**：這是富邦金的**壓艙石**。它的成長是**穩定且可預測的**，雖然不像壽險那樣具爆發力，但它在市場修正時能提供強力的獲利支撐。
#
# #### **C. 復甦與催化劑：富邦產險與富邦證券**
# *   **富邦產險**：已走出防疫險虧損的陰霾，回歸正常獲利軌道。這對整體獲利是「由負轉正」的貢獻，本身就是一種強力的成長動能。
# *   **富邦證券**：在台股日均成交量屢創新高的背景下，經紀業務手續費收入水漲船高，成為一個重要的獲利催化劑。
#
# **總結動能**：目前的成長動能非常強勁，但**「品質」上偏向資本市場驅動**。這意味著高獲利的可持續性，與股市的未來走向緊密相連。
#
# ---
#
# ### **2. 尋找突破訊號 (Breakthrough Signals)**
#
# 股價91.80元已是歷史相對高檔區，要尋找向上突破的訊號，我們需要從技術面、基本面和籌碼面共同觀察。
#
# #### **A. 技術面訊號 (Technical Signals)**
# 1.  **關鍵價位突破與站穩**：
#     *   **前高壓力區 (約 93-95 元)**：這是歷史性的天險，若能「帶量長紅」突破此區間，並在之後的幾個交易日回測不破，將是強烈的多頭攻擊訊號。
#     *   **整數關卡 (100 元)**：心理意義大於實質意義，一旦突破，可能引發市場追價意願。
# 2.  **量價關係**：
#     *   **價漲量增**：在攻擊關鍵價位時，成交量必須顯著放大（例如，超過月均量的1.5倍以上），顯示市場有足夠的換手與追價共識。
#     *   **價跌量縮**：回檔整理時，成交量萎縮，代表賣壓不重，籌碼趨於穩定。
# 3.  **均線型態**：
#     *   目前呈現標準的「多頭排列」（5日>10日>20日>60日均線），只要這個型態不被破壞（特別是股價不跌破月線），都屬於強勢整理格局。突破的基礎依然穩固。
#
# #### **B. 基本面/消息面訊號 (Fundamental Signals)**
# 1.  **超乎預期的月自結盈餘**：若未來幾個月，富邦金公布的單月EPS持續大幅優於市場預期（例如，在市場普遍預期0.8元時，開出1.5元），將會是股價上攻最直接的燃料。
# 2.  **美國聯準會（Fed）明確的降息訊號**：降息將有助於降低壽險公司的匯兌避險成本，並提升債券部位的價值，是金融股（特別是壽險股）的一大利多。市場若對降息預期升溫，將提前反應。
# 3.  **優於預期的股利政策**：明年董事會公布的股利若超出市場預期（例如，現金股利+股票股利合計超過市場普遍預估的3-3.5元），會吸引長期存股及高股息ETF資金進駐。
#
# #### **C. 籌碼面訊號 (Flow Signals)**
# 1.  **外資連續性大買**：富邦金是外資在台股的重要權值股標的。若外資從「間歇性買超」轉為「連續性、大規模買超」，將是股價突破的最重要推手。
# 2.  **投信ETF建倉/加碼**：若有新的高股息ETF將富邦金納入成分股，或現有ETF進行季度調整時大幅提高其權重，被動式買盤將提供穩定的股價支撐。
#
# ---
#
# ### **策略建議**
#
# 身為成長型投資顧問，我會這樣建議：
#
# 1.  **定義你的投資屬性**：
#     *   如果你是想賺取**趨勢財**：將富邦金視為「大型權值成長股」，緊盯上述的突破訊號。一旦訊號出現，順勢而為；但若股市反轉，其股價修正的風險也相對較高，需設定好停損點（例如跌破月線）。
#     *   如果你是追求**穩健成長**：將其視為「核心資產」，利用市場因短期利空（例如單月獲利不如預期、大盤回檔）拉回至季線附近時分批佈局，著眼於其長期穩定的銀行業務與股利政策。
#
# 2.  **目前的觀察點**：
#     *   股價在高檔區間震盪，屬於「攻擊前的蓄力」階段。多空正在此處交戰。
#     *   **不要在盤整區間內過度交易**。耐心等待明確的「帶量突破」訊號，或「拉回不破支撐」的訊號出現後再做決策。
#
# 3.  **後續追蹤清單**：
#     *   **每月10日前**：追蹤富邦金公布的自結盈餘。
#     *   **每日盤後**：觀察三大法人籌碼動向，特別是外資。
#     *   **每季**：關注美國聯準會的利率決策會議。
#
# 總結來說，富邦金目前的成長故事非常吸引人，但動力來源與風險相伴。理解其「順週期」的本質，並耐心等待明確的突破訊號，將是您在這支股票上取得成功的關鍵。
#
#
# ======================================================================
# 【2891 - 中信金】
# ======================================================================
# 您好，我是您的成長型投資顧問。很高興能為您分析中信金（2891）這檔股票。從成長型投資的角度來看，我們不僅要看見已實現的成長，更要評估未來成長的**品質**與**持續性**，並在技術面找到最佳的切入時機。
#
# 針對您提供的資料和關注點，我將從以下三個層面進行深入剖析：
#
# ### 1. 營收成長動能分析 (Fundamental Momentum)
#
# 您提供的數據「2025-09-30 營收成長 114.0%, EPS 1.28」非常引人注目。但作為顧問，我的職責是帶您看透數字背後的真相。
#
# **首先，我們要對這個「114.0%」的營收成長提出關鍵問題：**
#
# 對於中信金這樣龐大且成熟的金融控股公司，核心業務（銀行、保險、證券）要實現超過 100% 的年增長是極度罕見的。因此，這個驚人的數字極可能來自於**非經常性或一次性的事件**，而非本業的持續性爆發。
#
# **可能的驅動因素：**
# 1.  **壽險子公司投資收益**：金融市場大好時，壽險公司實現了大量的資本利得，這會被認列為營收。例如，處分大量股票或債券獲利。
# 2.  **併購案**：若中信金完成了某項大型併購，被併購公司的營收會被合併計算，導致帳面營收暴增。
# 3.  **會計準則變動**：例如 IFRS 17 的實施，可能改變了保險收入的認列方式，造成帳面數字的劇烈波動。
#
# **成長型投資者的核心課題：**
# 我們必須判斷這種成長是**「高品質且可持續的」**還是**「一次性的煙火」**。
#
# *   **高品質成長**：來自於銀行淨利息收入（NII）和手續費收入（NFI）的穩健增加、財富管理業務的規模擴張、海外市場的成功佈局。這才是我們樂見的。
# *   **低品質成長**：主要依賴一次性的投資收益。這種成長難以預測，也無法保證明年還會發生。
#
# **行動建議：**
# 您需要去檢視財報細節或關注公司法說會，釐清這 114% 成長的具體來源。如果確認核心業務（特別是銀行本業）的獲利能力也在同步提升，那這就是一個非常正面的訊號。反之，如果僅僅是一次性收益，我們在評估其長期價值時就必須保守一些。
#
# ---
#
# ### 2. 尋找突破訊號 (Technical Breakout)
#
# 股價 **43.75 元**，兩週上漲 **3.67%**，這顯示市場人氣正在聚集，股價處於一個相對強勢的狀態。從技術分析角度，我們可以尋找以下幾個潛在的「突破訊號」：
#
# **1. 關鍵價位突破與確認：**
# *   **歷史高點/平台整理區**：中信金股價已創下多年新高，突破了長期的壓力區。目前的價位本身就是一個重要的突破。
# *   **下一個訊號**：觀察股價是否能**帶量站穩在 43-44 元**這個新平台上。如果股價回檔測試這個區間不破，就形成了一個「壓力轉支撐」的強力訊號，代表市場認同這個新價位，後續上漲的基礎會更穩固。
#
# **2. 量價關係：**
# *   **價漲量增**：這是最健康的突破模式。當股價向上攻擊，例如挑戰 45 元整數關卡時，成交量必須同步放大。這代表有源源不絕的買盤願意在這個更高的價位追價，是市場集體共識的體現。
# *   **價漲量縮**：如果股價上漲，但成交量萎縮，需要提高警覺。這可能意味著追價意願不足，突破的力道可能無法持續。
#
# **3. 均線排列：**
# *   **多頭排列**：檢查日線圖或週線圖的均線（例如 5MA, 10MA, 20MA）是否呈現由上而下的依序排列。這種「多頭排列」格局代表短期、中期趨勢一致向上，是趨勢正在進行中的強力佐證。
#
# **4. 心理關卡：**
# *   **整數關卡**：接下來市場會關注 **45 元**和 **50 元**這兩個重要的心理關卡。每一次成功帶量突破整數關卡，都會吸引新一波的市場關注和資金流入。
#
# ---
#
# ### 綜合評估與成長型投資策略
#
# **目前情勢：**
# 中信金正處於一個「**基本面有題材、技術面已突破**」的有利格局。市場正在對其未來的獲利潛力（無論是一次性或持續性）進行重新定價（Re-rating）。
#
# **策略建議：**
#
# 1.  **分批佈局，控制節奏**：既然股價已在相對高檔，一次性重押風險較高。建議採用分批買入的策略。目前價位可以建立**基本部位**。
# 2.  **等待加碼的確認訊號**：真正的加碼點，應該是等待更明確的突破訊號出現。例如：
#     *   **帶量突破 45 元整數關卡。**
#     *   **股價回測 42-43 元支撐區不破，並再次上攻時。**
# 3.  **設定停損，嚴控風險**：成長股投資也需要紀律。如果股價不如預期，跌破了關鍵的支撐（例如月線或前波整理平台的下緣），就應果斷減碼或停損，保留資金等待下一個機會。
#
# **總結：**
# 中信金目前的動能非常強勁。作為成長型投資顧問，我認為它具備了短期內繼續向上挑戰的潛力。但我們的核心任務是**驗證其驚人營收背後的成長品質**。如果確認其核心業務穩健，那麼這次的技術性突破將有更堅實的基本面支撐，值得我們投入更多的信心與資金。
#
# 請持續關注公司財報與法說會的最新動態，並結合技術面的訊號來優化您的進出場策略。祝您投資順利！

# %%
reply = stock_analysis.stock_gimini_sort(str(content))
print(reply)
# Out:
# 好的，身為專業股票分析師，我已詳細研讀您提供的三份趨勢報告。以下我將根據報告內容的正面與負面訊息，進行評分與排序。
#
# **評分標準：**
# *   **基準分 (50分)：** 中性看待。
# *   **加分項：** 明確的技術面突破訊號、高品質且可持續的成長動能、多引擎獲利模式、結構性改善、分析師正面語氣（例如：「甦醒的巨象」、「順風週期」）。
# *   **扣分項：** 獲利來源過度依賴單一波動因素（如股市投資）、成長品質受質疑、面臨重大技術壓力、分析師提出明確風險警告。
#
# ---
#
# ### **個股分析與評分**
#
# #### **1. 2881 富邦金 (Fubon Financial)**
#
# **評分：75 / 100**
#
# **綜合評分理由：**
# 報告對富邦金的分析最為全面且正面。它描繪了一個「獲利三引擎（壽險、銀行、證券）全開」的強勁圖像，並且產險已走出陰霾，由負轉正。雖然其成長與股市高度相關，但其核心銀行業務提供了強大的穩定性，使其風險回報結構在三者中最佳。技術面雖未完全突破歷史天險，但處於「攻擊前的蓄力」階段，上檔潛力可期。
#
# *   **加分項：**
#     *   **[+15分] 多引擎成長動能：** 報告明確指出壽險（投資收益）、銀行（穩定利差與手收）、證券（高成交量）三大業務同步向好，且產險虧損因素消除，基本面最為強勁、全面。
#     *   **[+10分] 技術面強勢且明確：** 呈現標準的「多頭排列」，被形容為「攻擊前的蓄力」，顯示趨勢非常健康。
#     *   **[+5分] 明確的催化劑：** 報告點出如Fed降息、優於預期的股利等具體的基本面催化劑。
#
# *   **扣分項：**
#     *   **[-5分] 獲利品質的隱憂：** 報告強調當前獲利爆發的核心是「順週期性且波動性高」的投資收益，與大盤高度連動。
#
# ---
#
# #### **2. 2882 國泰金 (Cathay Financial)**
#
# **評分：70 / 100**
#
# **綜合評分理由：**
# 國泰金的報告揭示了最強的技術面訊號——突破長達20年的「超級大頸線」，這是一個極具意義的長期趨勢反轉訊號。基本面上，除了同樣受惠股市的投資收益外，報告特別點出「壽險業利差損的結構性改善」，這是一個高品質的長期利多。然而，相較於富邦金，報告中對其銀行業務等穩定引擎的著墨較少，使其成長故事略顯單一。
#
# *   **加分項：**
#     *   **[+20分] 極強的技術面突破：** 報告強調股價已站上「20年的超級大頸線」，壓力轉支撐，這是三份報告中最強烈的技術面看多理由。
#     *   **[+10分] 結構性改善利多：** 除了短期投資收益，報告點出了「利差損將逐步緩解」的長期、結構性利多，提升了成長的品質。
#     *   **[+5分] 分析師語氣正面：** 將其定位為「甦醒的金融巨象」，暗示其具備巨大的潛力。
#
# *   **扣分項：**
#     *   **[-10分] 獲利高度依賴股市：** 報告明確指出，獲利與股市高度連動是其主要風險，若市場修正將面臨壓力。
#     *   **[-5分] 報告起始數據為負值：** 提供的「營收成長-77.0%」數據，即便分析師解釋為雜訊，仍在第一印象中帶來負面觀感。
#
# ---
#
# #### **3. 2891 中信金 (CTBC Financial)**
#
# **評分：65 / 100**
#
# **綜合評分理由：**
# 中信金的報告呈現了一個「技術面已突破，但基本面待驗證」的情境。雖然股價創下多年新高，技術面非常強勢，但分析師花費大量篇幅質疑其「114%營收成長」的品質，認為可能是「一次性的煙火」。這種對核心成長動能的疑慮，使其長期投資的確定性相較前兩者為低。
#
# *   **加分項：**
#     *   **[+15分] 已確認的技術突破：** 報告指出股價已突破長期壓力區，創下新高，並形成「壓力轉支撐」的強力訊號。
#     *   **[+5分] 市場人氣聚集：** 近期股價表現強勢，顯示市場資金正在流入。
#
# *   **扣分項：**
#     *   **[-10分] 成長品質受到最大質疑：** 報告的核心論點之一，是其驚人的營收成長可能來自「非經常性或一次性的事件」，並非本業持續性爆發，這嚴重影響了其基本面的評分。
#     *   **[-5分] 缺乏多元成長故事：** 相較於國泰金的結構性改善和富邦金的多引擎驅動，中信金的報告更聚焦於單一數據的解讀，缺乏更豐富的長期成長論述。
#
# ---
#
# ### **總結與排序**
#
# 根據以上基於趨勢報告的評分，所有股票的展望均偏向正面（分數高於50），但其潛在的優勢與風險各不相同。
#
# **排序結果如下：**
#
# 1.  **第一名： `2881 富邦金` (評分: 75)**
#     *   **優勢：** 基本面最為全面且穩固，獲利引擎多元化，風險分散效果最佳。
#
# 2.  **第二名： `2882 國泰金` (評分: 70)**
#     *   **優勢：** 擁有最強的長線技術突破訊號，且具備長期結構性改善的題材，潛在爆發力強。
#
# 3.  **第三名： `2891 中信金` (評分: 65)**
#     *   **優勢：** 技術面已率先發動攻擊並站穩，短期趨勢強勁，但其驚人營收背後的成長品質有待後續財報驗證。
